# %% [markdown]
# <a href="https://colab.research.google.com/github/YumPastries-maker/FA3prgram/blob/main/FA3programming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Ask for student's name
name = input("Enter student's name: ")

#Ask for student's age
age = input("Enter student's age: ")

#Ask for student's course
course = input("Enter student's course: ")

#Display formatted output
print("--- Student Information ---")
print("Name:", name)
print("Age:", age)
print("Course:", course)
